# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import dash_html_components as html
import dash_core_components as dcc
# %matplotlib inline
mpl.style.use('ggplot')

# %%
car=pd.read_csv('Cleaned_Car_data.csv')

# %%
car
# Out:
#      Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0             0     Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1             1     Mahindra Jeep CL550  Mahindra  2006  425000          40
# 2             2       Hyundai Grand i10   Hyundai  2014  325000       28000
# 3             3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4             4               Ford Figo      Ford  2012  175000       41000
# ..          ...                     ...       ...   ...     ...         ...
# 811         811      Maruti Suzuki Ritz    Maruti  2011  270000       50000
# 812         812          Tata Indica V2      Tata  2009  110000       30000
# 813         813    Toyota Corolla Altis    Toyota  2009  300000      132000
# 814         814            Tata Zest XM      Tata  2018  260000       27000
# 815         815      Mahindra Quanto C8  Mahindra  2013  390000       40000
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Diesel
# 4      Diesel
# ..        ...
# 811    Petrol
# 812    Diesel
# 813    Petrol
# 814    Diesel
# 815    Diesel
#
# [816 rows x 7 columns]

# %%
car=car[car['Price']<6000000]

# %%
X=car[['name','company','year','kms_driven','fuel_type']]
y=car['Price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),
                                    remainder='passthrough')

# %%
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
#                                                                             array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['name', 'company',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.5833328364287172

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
scores[np.argmax(scores)]
# Out:
# 0.9200894544056878

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
import dash
from dash.dependencies import Input,Output
app = dash.Dash(__name__)

# %%
name = car['name']
name = list(set(name))
name.sort()
model=[]
for i in name:
    model.append({"label":i,"value":i})
model
# Out:
# [{'label': 'Audi A3 Cabriolet', 'value': 'Audi A3 Cabriolet'},
#  {'label': 'Audi A4 1.8', 'value': 'Audi A4 1.8'},
#  {'label': 'Audi A4 2.0', 'value': 'Audi A4 2.0'},
#  {'label': 'Audi A6 2.0', 'value': 'Audi A6 2.0'},
#  {'label': 'Audi A8', 'value': 'Audi A8'},
#  {'label': 'Audi Q3 2.0', 'value': 'Audi Q3 2.0'},
#  {'label': 'Audi Q5 2.0', 'value': 'Audi Q5 2.0'},
#  {'label': 'Audi Q7', 'value': 'Audi Q7'},
#  {'label': 'BMW 3 Series', 'value': 'BMW 3 Series'},
#  {'label': 'BMW 5 Series', 'value': 'BMW 5 Series'},
#  {'label': 'BMW 7 Series', 'value': 'BMW 7 Series'},
#  {'label': 'BMW X1', 'value': 'BMW X1'},
#  {'label': 'BMW X1 sDrive20d', 'value': 'BMW X1 sDrive20d'},
#  {'label': 'BMW X1 xDrive20d', 'value': 'BMW X1 xDrive20d'},
#  {'label': 'Chevrolet Beat', 'value': 'Chevrolet Beat'},
#  {'label': 'Chevrolet Beat Diesel', 'value': 'Chevrolet Beat Diesel'},
#  {'label': 'Chevrolet Beat LS', 'value': 'Chevrolet Beat LS'},
#  {'label': 'Chevrolet Beat LT', 'value': 'Chevrolet Beat LT'},
#  {'label': 'Chevrolet Beat PS', 'value': 'Chevrolet Beat PS'},
#  {'label': 'Chevrolet Cruze LTZ', 'value': 'Chevrolet Cruze LTZ'},
#  {'label': 'Chevrolet Enjoy', 'value': 'Chevrolet Enjoy'},
#  {'label': 'Chevrolet Enjoy 1.4', 'value': 'Chevrolet Enjoy 1.4'},
#  {'label': 'Chevrolet Sail 1.2', 'value': 'Chevrolet Sail 1.2'},
#  {'label': 'Chevrolet Sail UVA', 'value': 'Chevrolet Sail UVA'},
#  {'label': 'Chevrolet Spark', 'value': 'Chevrolet Spark'},
#  {'label': 'Chevrolet Spark 1.0', 'value': 'Chevrolet Spark 1.0'},
#  {'label': 'Chevrolet Spark LS', 'value': 'Chevrolet Spark LS'},
#  {'label': 'Chevrolet Spark LT', 'value': 'Chevrolet Spark LT'},
#  {'label': 'Chevrolet Tavera LS', 'value': 'Chevrolet Tavera LS'},
#  {'label': 'Chevrolet Tavera Neo', 'value': 'Chevrolet Tavera Neo'},
#  {'label': 'Datsun GO T', 'value': 'Datsun GO T'},
#  {'label': 'Datsun Go Plus', 'value': 'Datsun Go Plus'},
#  {'label': 'Datsun Redi GO', 'value': 'Datsun Redi GO'},
#  {'label': 'Fiat Linea Emotion', 'value': 'Fiat Linea Emotion'},
#  {'label': 'Fiat Petra ELX', 'value': 'Fiat Petra ELX'},
#  {'label': 'Fiat Punto Emotion', 'value': 'Fiat Punto Emotion'},
#  {'label': 'Force Motors Force', 'value': 'Force Motors Force'},
#  {'label': 'Force Motors One', 'value': 'Force Motors One'},
#  {'label': 'Ford EcoSport', 'value': 'Ford EcoSport'},
#  {'label': 'Ford EcoSport Ambiente', 'value': 'Ford EcoSport Ambiente'},
#  {'label': 'Ford EcoSport Titanium', 'value': 'Ford EcoSport Titanium'},
#  {'label': 'Ford EcoSport Trend', 'value': 'Ford EcoSport Trend'},
#  {'label': 'Ford Endeavor 4x4', 'value': 'Ford Endeavor 4x4'},
#  {'label': 'Ford Fiesta', 'value': 'Ford Fiesta'},
#  {'label': 'Ford Fiesta SXi', 'value': 'Ford Fiesta SXi'},
#  {'label': 'Ford Figo', 'value': 'Ford Figo'},
#  {'label': 'Ford Figo Diesel', 'value': 'Ford Figo Diesel'},
#  {'label': 'Ford Figo Duratorq', 'value': 'Ford Figo Duratorq'},
#  {'label': 'Ford Figo Petrol', 'value': 'Ford Figo Petrol'},
#  {'label': 'Ford Fusion 1.4', 'value': 'Ford Fusion 1.4'},
#  {'label': 'Ford Ikon 1.3', 'value': 'Ford Ikon 1.3'},
#  {'label': 'Ford Ikon 1.6', 'value': 'Ford Ikon 1.6'},
#  {'label': 'Hindustan Motors Ambassador',
#   'value': 'Hindustan Motors Ambassador'},
#  {'label': 'Honda Accord', 'value': 'Honda Accord'},
#  {'label': 'Honda Amaze', 'value': 'Honda Amaze'},
#  {'label': 'Honda Amaze 1.2', 'value': 'Honda Amaze 1.2'},
#  {'label': 'Honda Amaze 1.5', 'value': 'Honda Amaze 1.5'},
#  {'label': 'Honda Brio', 'value': 'Honda Brio'},
#  {'label': 'Honda Brio V', 'value': 'Honda Brio V'},
#  {'label': 'Honda Brio VX', 'value': 'Honda Brio VX'},
#  {'label': 'Honda City', 'value': 'Honda City'},
#  {'label': 'Honda City 1.5', 'value': 'Honda City 1.5'},
#  {'label': 'Honda City SV', 'value': 'Honda City SV'},
#  {'label': 'Honda City VX', 'value': 'Honda City VX'},
#  {'label': 'Honda City ZX', 'value': 'Honda City ZX'},
#  {'label': 'Honda Jazz S', 'value': 'Honda Jazz S'},
#  {'label': 'Honda Jazz VX', 'value': 'Honda Jazz VX'},
#  {'label': 'Honda Mobilio', 'value': 'Honda Mobilio'},
#  {'label': 'Honda Mobilio S', 'value': 'Honda Mobilio S'},
#  {'label': 'Honda WR V', 'value': 'Honda WR V'},
#  {'label': 'Hyundai Accent', 'value': 'Hyundai Accent'},
#  {'label': 'Hyundai Accent Executive', 'value': 'Hyundai Accent Executive'},
#  {'label': 'Hyundai Accent GLE', 'value': 'Hyundai Accent GLE'},
#  {'label': 'Hyundai Accent GLX', 'value': 'Hyundai Accent GLX'},
#  {'label': 'Hyundai Creta', 'value': 'Hyundai Creta'},
#  {'label': 'Hyundai Creta 1.6', 'value': 'Hyundai Creta 1.6'},
#  {'label': 'Hyundai Elantra 1.8', 'value': 'Hyundai Elantra 1.8'},
#  {'label': 'Hyundai Elantra SX', 'value': 'Hyundai Elantra SX'},
#  {'label': 'Hyundai Elite i20', 'value': 'Hyundai Elite i20'},
#  {'label': 'Hyundai Eon', 'value': 'Hyundai Eon'},
#  {'label': 'Hyundai Eon D', 'value': 'Hyundai Eon D'},
#  {'label': 'Hyundai Eon Era', 'value': 'Hyundai Eon Era'},
#  {'label': 'Hyundai Eon Magna', 'value': 'Hyundai Eon Magna'},
#  {'label': 'Hyundai Eon Sportz', 'value': 'Hyundai Eon Sportz'},
#  {'label': 'Hyundai Fluidic Verna', 'value': 'Hyundai Fluidic Verna'},
#  {'label': 'Hyundai Getz', 'value': 'Hyundai Getz'},
#  {'label': 'Hyundai Getz GLE', 'value': 'Hyundai Getz GLE'},
#  {'label': 'Hyundai Getz Prime', 'value': 'Hyundai Getz Prime'},
#  {'label': 'Hyundai Grand i10', 'value': 'Hyundai Grand i10'},
#  {'label': 'Hyundai Santro', 'value': 'Hyundai Santro'},
#  {'label': 'Hyundai Santro AE', 'value': 'Hyundai Santro AE'},
#  {'label': 'Hyundai Santro Xing', 'value': 'Hyundai Santro Xing'},
#  {'label': 'Hyundai Sonata Transform', 'value': 'Hyundai Sonata Transform'},
#  {'label': 'Hyundai Verna', 'value': 'Hyundai Verna'},
#  {'label': 'Hyundai Verna 1.4', 'value': 'Hyundai Verna 1.4'},
#  {'label': 'Hyundai Verna 1.6', 'value': 'Hyundai Verna 1.6'},
#  {'label': 'Hyundai Verna Fluidic', 'value': 'Hyundai Verna Fluidic'},
#  {'label': 'Hyundai Verna Transform', 'value': 'Hyundai Verna Transform'},
#  {'label': 'Hyundai Verna VGT', 'value': 'Hyundai Verna VGT'},
#  {'label': 'Hyundai Xcent Base', 'value': 'Hyundai Xcent Base'},
#  {'label': 'Hyundai Xcent SX', 'value': 'Hyundai Xcent SX'},
#  {'label': 'Hyundai i10', 'value': 'Hyundai i10'},
#  {'label': 'Hyundai i10 Era', 'value': 'Hyundai i10 Era'},
#  {'label': 'Hyundai i10 Magna', 'value': 'Hyundai i10 Magna'},
#  {'label': 'Hyundai i10 Sportz', 'value': 'Hyundai i10 Sportz'},
#  {'label': 'Hyundai i20', 'value': 'Hyundai i20'},
#  {'label': 'Hyundai i20 Active', 'value': 'Hyundai i20 Active'},
#  {'label': 'Hyundai i20 Asta', 'value': 'Hyundai i20 Asta'},
#  {'label': 'Hyundai i20 Magna', 'value': 'Hyundai i20 Magna'},
#  {'label': 'Hyundai i20 Select', 'value': 'Hyundai i20 Select'},
#  {'label': 'Hyundai i20 Sportz', 'value': 'Hyundai i20 Sportz'},
#  {'label': 'Jaguar XE XE', 'value': 'Jaguar XE XE'},
#  {'label': 'Jaguar XF 2.2', 'value': 'Jaguar XF 2.2'},
#  {'label': 'Jeep Wrangler Unlimited', 'value': 'Jeep Wrangler Unlimited'},
#  {'label': 'Land Rover Freelander', 'value': 'Land Rover Freelander'},
#  {'label': 'Mahindra Bolero DI', 'value': 'Mahindra Bolero DI'},
#  {'label': 'Mahindra Bolero Power', 'value': 'Mahindra Bolero Power'},
#  {'label': 'Mahindra Bolero SLE', 'value': 'Mahindra Bolero SLE'},
#  {'label': 'Mahindra Jeep CL550', 'value': 'Mahindra Jeep CL550'},
#  {'label': 'Mahindra Jeep MM', 'value': 'Mahindra Jeep MM'},
#  {'label': 'Mahindra KUV100', 'value': 'Mahindra KUV100'},
#  {'label': 'Mahindra KUV100 K8', 'value': 'Mahindra KUV100 K8'},
#  {'label': 'Mahindra Logan', 'value': 'Mahindra Logan'},
#  {'label': 'Mahindra Logan Diesel', 'value': 'Mahindra Logan Diesel'},
#  {'label': 'Mahindra Quanto C4', 'value': 'Mahindra Quanto C4'},
#  {'label': 'Mahindra Quanto C8', 'value': 'Mahindra Quanto C8'},
#  {'label': 'Mahindra Scorpio', 'value': 'Mahindra Scorpio'},
#  {'label': 'Mahindra Scorpio 2.6', 'value': 'Mahindra Scorpio 2.6'},
#  {'label': 'Mahindra Scorpio LX', 'value': 'Mahindra Scorpio LX'},
#  {'label': 'Mahindra Scorpio S10', 'value': 'Mahindra Scorpio S10'},
#  {'label': 'Mahindra Scorpio S4', 'value': 'Mahindra Scorpio S4'},
#  {'label': 'Mahindra Scorpio SLE', 'value': 'Mahindra Scorpio SLE'},
#  {'label': 'Mahindra Scorpio SLX', 'value': 'Mahindra Scorpio SLX'},
#  {'label': 'Mahindra Scorpio VLX', 'value': 'Mahindra Scorpio VLX'},
#  {'label': 'Mahindra Scorpio Vlx', 'value': 'Mahindra Scorpio Vlx'},
#  {'label': 'Mahindra Scorpio W', 'value': 'Mahindra Scorpio W'},
#  {'label': 'Mahindra TUV300 T4', 'value': 'Mahindra TUV300 T4'},
#  {'label': 'Mahindra TUV300 T8', 'value': 'Mahindra TUV300 T8'},
#  {'label': 'Mahindra Thar CRDe', 'value': 'Mahindra Thar CRDe'},
#  {'label': 'Mahindra XUV500', 'value': 'Mahindra XUV500'},
#  {'label': 'Mahindra XUV500 W10', 'value': 'Mahindra XUV500 W10'},
#  {'label': 'Mahindra XUV500 W6', 'value': 'Mahindra XUV500 W6'},
#  {'label': 'Mahindra XUV500 W8', 'value': 'Mahindra XUV500 W8'},
#  {'label': 'Mahindra Xylo D2', 'value': 'Mahindra Xylo D2'},
#  {'label': 'Mahindra Xylo E4', 'value': 'Mahindra Xylo E4'},
#  {'label': 'Mahindra Xylo E8', 'value': 'Mahindra Xylo E8'},
#  {'label': 'Maruti Suzuki 800', 'value': 'Maruti Suzuki 800'},
#  {'label': 'Maruti Suzuki A', 'value': 'Maruti Suzuki A'},
#  {'label': 'Maruti Suzuki Alto', 'value': 'Maruti Suzuki Alto'},
#  {'label': 'Maruti Suzuki Baleno', 'value': 'Maruti Suzuki Baleno'},
#  {'label': 'Maruti Suzuki Celerio', 'value': 'Maruti Suzuki Celerio'},
#  {'label': 'Maruti Suzuki Ciaz', 'value': 'Maruti Suzuki Ciaz'},
#  {'label': 'Maruti Suzuki Dzire', 'value': 'Maruti Suzuki Dzire'},
#  {'label': 'Maruti Suzuki Eeco', 'value': 'Maruti Suzuki Eeco'},
#  {'label': 'Maruti Suzuki Ertiga', 'value': 'Maruti Suzuki Ertiga'},
#  {'label': 'Maruti Suzuki Esteem', 'value': 'Maruti Suzuki Esteem'},
#  {'label': 'Maruti Suzuki Estilo', 'value': 'Maruti Suzuki Estilo'},
#  {'label': 'Maruti Suzuki Maruti', 'value': 'Maruti Suzuki Maruti'},
#  {'label': 'Maruti Suzuki Omni', 'value': 'Maruti Suzuki Omni'},
#  {'label': 'Maruti Suzuki Ritz', 'value': 'Maruti Suzuki Ritz'},
#  {'label': 'Maruti Suzuki S', 'value': 'Maruti Suzuki S'},
#  {'label': 'Maruti Suzuki SX4', 'value': 'Maruti Suzuki SX4'},
#  {'label': 'Maruti Suzuki Stingray', 'value': 'Maruti Suzuki Stingray'},
#  {'label': 'Maruti Suzuki Swift', 'value': 'Maruti Suzuki Swift'},
#  {'label': 'Maruti Suzuki Versa', 'value': 'Maruti Suzuki Versa'},
#  {'label': 'Maruti Suzuki Vitara', 'value': 'Maruti Suzuki Vitara'},
#  {'label': 'Maruti Suzuki Wagon', 'value': 'Maruti Suzuki Wagon'},
#  {'label': 'Maruti Suzuki Zen', 'value': 'Maruti Suzuki Zen'},
#  {'label': 'Mercedes Benz A', 'value': 'Mercedes Benz A'},
#  {'label': 'Mercedes Benz B', 'value': 'Mercedes Benz B'},
#  {'label': 'Mercedes Benz C', 'value': 'Mercedes Benz C'},
#  {'label': 'Mercedes Benz GLA', 'value': 'Mercedes Benz GLA'},
#  {'label': 'Mini Cooper S', 'value': 'Mini Cooper S'},
#  {'label': 'Mitsubishi Lancer 1.8', 'value': 'Mitsubishi Lancer 1.8'},
#  {'label': 'Mitsubishi Pajero Sport', 'value': 'Mitsubishi Pajero Sport'},
#  {'label': 'Nissan Micra XL', 'value': 'Nissan Micra XL'},
#  {'label': 'Nissan Micra XV', 'value': 'Nissan Micra XV'},
#  {'label': 'Nissan Sunny', 'value': 'Nissan Sunny'},
#  {'label': 'Nissan Sunny XL', 'value': 'Nissan Sunny XL'},
#  {'label': 'Nissan Terrano XL', 'value': 'Nissan Terrano XL'},
#  {'label': 'Nissan X Trail', 'value': 'Nissan X Trail'},
#  {'label': 'Renault Duster', 'value': 'Renault Duster'},
#  {'label': 'Renault Duster 110', 'value': 'Renault Duster 110'},
#  {'label': 'Renault Duster 110PS', 'value': 'Renault Duster 110PS'},
#  {'label': 'Renault Duster 85', 'value': 'Renault Duster 85'},
#  {'label': 'Renault Duster 85PS', 'value': 'Renault Duster 85PS'},
#  {'label': 'Renault Duster RxL', 'value': 'Renault Duster RxL'},
#  {'label': 'Renault Kwid', 'value': 'Renault Kwid'},
#  {'label': 'Renault Kwid 1.0', 'value': 'Renault Kwid 1.0'},
#  {'label': 'Renault Kwid RXT', 'value': 'Renault Kwid RXT'},
#  {'label': 'Renault Lodgy 85', 'value': 'Renault Lodgy 85'},
#  {'label': 'Renault Scala RxL', 'value': 'Renault Scala RxL'},
#  {'label': 'Skoda Fabia', 'value': 'Skoda Fabia'},
#  {'label': 'Skoda Fabia 1.2L', 'value': 'Skoda Fabia 1.2L'},
#  {'label': 'Skoda Fabia Classic', 'value': 'Skoda Fabia Classic'},
#  {'label': 'Skoda Laura', 'value': 'Skoda Laura'},
#  {'label': 'Skoda Octavia Classic', 'value': 'Skoda Octavia Classic'},
#  {'label': 'Skoda Rapid Elegance', 'value': 'Skoda Rapid Elegance'},
#  {'label': 'Skoda Superb 1.8', 'value': 'Skoda Superb 1.8'},
#  {'label': 'Skoda Yeti Ambition', 'value': 'Skoda Yeti Ambition'},
#  {'label': 'Tata Aria Pleasure', 'value': 'Tata Aria Pleasure'},
#  {'label': 'Tata Bolt XM', 'value': 'Tata Bolt XM'},
#  {'label': 'Tata Indica', 'value': 'Tata Indica'},
#  {'label': 'Tata Indica V2', 'value': 'Tata Indica V2'},
#  {'label': 'Tata Indica eV2', 'value': 'Tata Indica eV2'},
#  {'label': 'Tata Indigo CS', 'value': 'Tata Indigo CS'},
#  {'label': 'Tata Indigo LS', 'value': 'Tata Indigo LS'},
#  {'label': 'Tata Indigo LX', 'value': 'Tata Indigo LX'},
#  {'label': 'Tata Indigo Marina', 'value': 'Tata Indigo Marina'},
#  {'label': 'Tata Indigo eCS', 'value': 'Tata Indigo eCS'},
#  {'label': 'Tata Manza', 'value': 'Tata Manza'},
#  {'label': 'Tata Manza Aqua', 'value': 'Tata Manza Aqua'},
#  {'label': 'Tata Manza Aura', 'value': 'Tata Manza Aura'},
#  {'label': 'Tata Manza ELAN', 'value': 'Tata Manza ELAN'},
#  {'label': 'Tata Nano', 'value': 'Tata Nano'},
#  {'label': 'Tata Nano Cx', 'value': 'Tata Nano Cx'},
#  {'label': 'Tata Nano GenX', 'value': 'Tata Nano GenX'},
#  {'label': 'Tata Nano LX', 'value': 'Tata Nano LX'},
#  {'label': 'Tata Nano Lx', 'value': 'Tata Nano Lx'},
#  {'label': 'Tata Sumo Gold', 'value': 'Tata Sumo Gold'},
#  {'label': 'Tata Sumo Grande', 'value': 'Tata Sumo Grande'},
#  {'label': 'Tata Sumo Victa', 'value': 'Tata Sumo Victa'},
#  {'label': 'Tata Tiago Revotorq', 'value': 'Tata Tiago Revotorq'},
#  {'label': 'Tata Tiago Revotron', 'value': 'Tata Tiago Revotron'},
#  {'label': 'Tata Tigor Revotron', 'value': 'Tata Tigor Revotron'},
#  {'label': 'Tata Venture EX', 'value': 'Tata Venture EX'},
#  {'label': 'Tata Vista Quadrajet', 'value': 'Tata Vista Quadrajet'},
#  {'label': 'Tata Zest Quadrajet', 'value': 'Tata Zest Quadrajet'},
#  {'label': 'Tata Zest XE', 'value': 'Tata Zest XE'},
#  {'label': 'Tata Zest XM', 'value': 'Tata Zest XM'},
#  {'label': 'Toyota Corolla', 'value': 'Toyota Corolla'},
#  {'label': 'Toyota Corolla Altis', 'value': 'Toyota Corolla Altis'},
#  {'label': 'Toyota Corolla H2', 'value': 'Toyota Corolla H2'},
#  {'label': 'Toyota Etios', 'value': 'Toyota Etios'},
#  {'label': 'Toyota Etios G', 'value': 'Toyota Etios G'},
#  {'label': 'Toyota Etios GD', 'value': 'Toyota Etios GD'},
#  {'label': 'Toyota Etios Liva', 'value': 'Toyota Etios Liva'},
#  {'label': 'Toyota Fortuner', 'value': 'Toyota Fortuner'},
#  {'label': 'Toyota Fortuner 3.0', 'value': 'Toyota Fortuner 3.0'},
#  {'label': 'Toyota Innova 2.0', 'value': 'Toyota Innova 2.0'},
#  {'label': 'Toyota Innova 2.5', 'value': 'Toyota Innova 2.5'},
#  {'label': 'Toyota Qualis', 'value': 'Toyota Qualis'},
#  {'label': 'Volkswagen Jetta Comfortline',
#   'value': 'Volkswagen Jetta Comfortline'},
#  {'label': 'Volkswagen Jetta Highline', 'value': 'Volkswagen Jetta Highline'},
#  {'label': 'Volkswagen Passat Diesel', 'value': 'Volkswagen Passat Diesel'},
#  {'label': 'Volkswagen Polo', 'value': 'Volkswagen Polo'},
#  {'label': 'Volkswagen Polo Comfortline',
#   'value': 'Volkswagen Polo Comfortline'},
#  {'label': 'Volkswagen Polo Highline', 'value': 'Volkswagen Polo Highline'},
#  {'label': 'Volkswagen Polo Highline1.2L',
#   'value': 'Volkswagen Polo Highline1.2L'},
#  {'label': 'Volkswagen Polo Trendline', 'value': 'Volkswagen Polo Trendline'},
#  {'label': 'Volkswagen Vento Comfortline',
#   'value': 'Volkswagen Vento Comfortline'},
#  {'label': 'Volkswagen Vento Highline', 'value': 'Volkswagen Vento Highline'},
#  {'label': 'Volkswagen Vento Konekt', 'value': 'Volkswagen Vento Konekt'},
#  {'label': 'Volvo S80 Summum', 'value': 'Volvo S80 Summum'}]

# %%
app.layout = html.Div([
    html.H2("Sales Analysis"),
    html.Img(src='/assets/data.jpg'),
    html.Hr(),
    html.Div([
        html.H4('Choose Model   '),
        html.Br(),
        dcc.Dropdown(
        id = "model_id",
            options=model,
                value=model[0]
        ),
    ],className='dropdown'),
    html.Div([
        html.H4('Enter Brand'),
        html.Br(),
        dcc.Input(
        id = "brand",type='text',placeholder='Enter Brand'
        )
    ]),
    html.Div([
        html.H4('Enter Year'),
        html.Br(),
        dcc.Input(
        id = "year",type='number',placeholder='Enter model Year'
        )
    ]),
    html.Div([
        html.H4('Enter Kms Driven'),
        html.Br(),
        dcc.Input(
        id = "kms",type='number',placeholder='Enter Kilometer-Driven'
        )
    ]),
    html.Div([
        html.H4('Enter fuel-type'),
        html.Br(),
        dcc.Input(
        id = "fuel",type='text',placeholder='Enter Fuel-Type'
        )
        
    ]),
    html.Div(
        html.H1(id="output")
    ),
],className='banner')

@app.callback(
    Output("output","children"),
    Input("model_id","value"),
    Input("brand","value"),
)
def update_output(model_id,brand):
    return u'Input 1 {} and Input 2 {}'.format(model_id, brand)

# %%
if __name__ == "__main__":
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [29/May/2021 00:15:00] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [29/May/2021 00:15:01] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [29/May/2021 00:15:01] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [29/May/2021 00:15:01] "GET /_favicon.ico?v=1.20.0 HTTP/1.1" 200 -

# %%
pipe.predict(pd.DataFrame(columns=['name','company','year','kms_driven','fuel_type'],data=np.array(['Maruti Suzuki Alto','Maruti',2019,100,'Petrol']).reshape(1,5)))
# Out:
# array([316609.61993986])
